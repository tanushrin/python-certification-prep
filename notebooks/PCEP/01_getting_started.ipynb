# %% [markdown]
# # 📘 PCEP Practice Notebook - Getting Started
#
# This notebook provides interactive examples for Python Certified Entry-Level Programmer (PCEP) preparation.
#
# ## How to Use This Notebook
# 1. Read each section carefully
# 2. Run the code cells to see the output
# 3. Modify the code to experiment
# 4. Complete the practice exercises

# %% [markdown]
# ## Chapter 1: Basic Python Concepts
#
# Let's start with fundamental Python concepts:

# %%
# Basic print statement
print("Hello, Python Certification Prep!")
print("Welcome to interactive learning")

# %% [markdown]
# ### Variables and Data Types

# %%
# Variables and basic data types
name = "Alice"
age = 25
height = 5.6
is_student = True

print(f"Name: {name} (type: {type(name)})")
print(f"Age: {age} (type: {type(age)})")
print(f"Height: {height} (type: {type(height)})")
print(f"Is Student: {is_student} (type: {type(is_student)})")

# %% [markdown]
# ### Practice Exercise 1
# Create variables for your own information and print them:

# %%
# TODO: Create your own variables here
# my_name = 
# my_age = 
# my_favorite_number = 

# Print them using f-strings

# %% [markdown]
# ### Basic Operators

# %%
# Arithmetic operators
a = 10
b = 3

print(f"Addition: {a} + {b} = {a + b}")
print(f"Subtraction: {a} - {b} = {a - b}")
print(f"Multiplication: {a} * {b} = {a * b}")
print(f"Division: {a} / {b} = {a / b}")
print(f"Floor Division: {a} // {b} = {a // b}")
print(f"Modulo: {a} % {b} = {a % b}")
print(f"Exponentiation: {a} ** {b} = {a ** b}")

# %% [markdown]
# ### Practice Exercise 2
# Complete the following calculations:

# %%
# Calculate the area of a rectangle
length = 8
width = 5
# area = 

# Calculate the circumference of a circle (use 3.14159 for pi)
radius = 7
pi = 3.14159
# circumference = 

print(f"Rectangle area: {area}")
print(f"Circle circumference: {circumference}")

# %% [markdown]
# ## Next Steps
#
# This is just the beginning! Continue with:
# - More complex data types (lists, dictionaries, tuples)
# - Control structures (if/else, loops)
# - Functions
# - File handling
#
# Check out the other notebooks in this directory for more topics!
